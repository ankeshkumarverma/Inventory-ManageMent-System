# %% [markdown]
# ## Loading my Records file

# %%
# !git clone https://github.com/AshishJangra27/Skill-India-AI-ML-Scholarship
# Out:
# Cloning into 'Skill-India-AI-ML-Scholarship'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 81 (delta 31), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (81/81), done.

# %% [markdown]
# ## Generating Sales and Record file for the first time

# %%
fd = open('/content/Skill-India-AI-ML-Scholarship/JSON Based Inventory management Assignment/record.json', 'r')
t = fd.read()
fd.close()

fd = open('record.json','w')
fd.write(t)
fd.close()

sales = {}

sales = json.dumps(sales)

fd = open("sales.json", 'w')
fd.write(sales)
fd.close()

# %% [markdown]
# ## Importing Libraries

# %%
import json
import time

# %%
# Loading Inventory and Converting it to Dictionary
fd = open('record.json','r')
t = fd.read()
fd.close()
dct = json.loads(t)

# Loading Sales and Converting it to Dictionary
fd = open("sale.json", 'r')
sl = fd.read()
fd.close()
sales = json.loads(sl)


# Displaying Menu
print("**********************************************")
for i in dct.keys():
  print(i, dct[i])

print("******************************************\n")

# Taking Input from User to Enter what he/she wants to purchase
ui_prod  = str(input("Enter the product_Id: "))
ui_quant = int(input("Enter the quantity: "))


if (ui_prod in dct.keys()):                                                     # Checking If product Exists or not
    if (dct[ui_prod]['qn'] >= ui_quant):                                        # If I'm having enough Quantity
      print("Name:",dct[ui_prod]['name'])
      print("Price:",dct[ui_prod]['pr'])
      print("Quantity:", ui_quant)
      print("------------------------------")
      print("Billing Amount:", dct[ui_prod]['pr'] * ui_quant)

      dct[ui_prod]['qn'] = dct[ui_prod]['qn'] - ui_quant                        # Updating Inventory

      sales[str(len(sales)+1)] = {'prod_id' : ui_prod,                          # Updating Transection
                                  "time_pr" :  time.ctime(), 
                                  'bill' : dct[ui_prod]['pr'] * ui_quant, 
                                  'qn' : ui_quant, 
                                  'pr' : dct[ui_prod]['pr'], 
                                  'pr_name' : dct[ui_prod]['name']}


    else:                                                                       # If I'm not having enough Quantity
      print("Sorry, We are not having that much of quantity.")
      print("We're only having",dct[ui_prod]['qn'],"quantity.")
      print("Would you like to purchase or not (Y/N)")
      ch = str(input("Y/N"))

      if (ch == "Y"):                                                           # If user wants to purchase the quantitry we're having
        print("Name:",dct[ui_prod]['name'])
        print("Price:",dct[ui_prod]['pr'])
        print("Quantity:", dct[ui_prod]['qn'])
        print("------------------------------")
        print("Billing Amount:", dct[ui_prod]['pr'] * dct[ui_prod]['qn'])

        dct[ui_prod]['qn'] = 0                                                  # Updating Inventory

        sales[str(len(sales)+1)] = {'prod_id' : ui_prod,                        # Updating Transection
                                    "time_pr" :  time.ctime(), 
                                    'bill' : dct[ui_prod]['pr'] * dct[ui_prod]['qn'], 
                                    'qn' : dct[ui_prod]['qn'], 
                                    'pr' : dct[ui_prod]['pr'], 
                                    'pr_name' : dct[ui_prod]['name']}

      else:                                                                     # If user press anything Except Y
        print("Thankyou!")

else:                                                                           # Product ID Doesn't exists
  print("------------------------------")
  print("Product doesn't exist!")
  print("Please enter a valid product id")
  print("------------------------------")



sl = json.dumps(sales)                                                          # Updating Sales File
fd = open('sale.json','w')
fd.write(sl)
fd.close()

print("------------------------------")
print("Data Updated in Sales File!")

js = json.dumps(dct)                                                            # Updating Inventory File
fd = open('record.json','w')
fd.write(js)
fd.close()

print("Data Updated in Inventory File!")
# Out:
# **********************************************
# 1001 {'name': 'Mobile', 'qn': 34, 'pr': 10000, 'brand': 'Realme', 'customer_rating': 4, 'type': 'Smartphone', 'color': 'Black', 'category': 'Mobiles', 'size': 7.0, 'made_in': 'India', 'ideal_for': '18+'}
# 1002 {'name': 'Milk Cake', 'pr': 800, 'qn': 100, 'brand': 'Amool', 'customer_rating': 5, 'type': 'Bakery', 'color': 'Black', 'category': 'Beverage', 'size': 20.0, 'made_in': 'India', 'ideal_for': 'All'}
# 1003 {'name': 'Drink', 'pr': 85, 'qn': 100, 'brand': 'Coca', 'customer_rating': 4, 'type': 'Drinks', 'color': 'Black', 'category': 'Beverage', 'size': 2.0, 'made_in': 'India', 'ideal_for': 'All'}
# 1004 {'name': 'Candy', 'pr': 5, 'qn': 1000, 'brand': 'Crush', 'customer_rating': 2, 'type': 'Time Pass', 'color': 'White', 'category': 'Beverage', 'size': 7.0, 'made_in': 'USA', 'ideal_for': 'All'}
# 1005 {'name': 'Pen', 'pr': 20, 'qn': 100, 'brand': 'Golden Delta', 'customer_rating': 4, 'type': 'Writing Pen', 'color': 'Red', 'category': 'Stationary', 'size': 0.0, 'made_in': 'French', 'ideal_for': 'All'}
# 1006 {'name': 'Laptop', 'pr': 50000, 'qn': 10, 'brand': 'Lenovo', 'customer_rating': 4, 'type': 'Computer', 'color': 'Black', 'category': 'Electronic', 'size': 0.0, 'made_in': 'China', 'ideal_for': '18+'}
# 1007 {'name': 'Mic', 'pr': 1500, 'qn': 0, 'brand': 'Boat', 'customer_rating': 4, 'type': 'Audio_input', 'color': 'Grey', 'category': 'Electronics', 'size': 0.0, 'made_in': 'Japan', 'ideal_for': '18+'}
# 1008 {'name': 'Smart Watch', 'pr': 1999, 'qn': 5, 'brand': 'Realme', 'customer_rating': 5, 'type': 'Hand Watch', 'color': 'Orange', 'category': 'Electronic', 'size': 5.0, 'made_in': 'India', 'ideal_for': '18+'}
# 1009 {'name': 'Keyboard', 'pr': 1999, 'qn': 10, 'brand': 'PanaSonic', 'customer_rating': 4, 'type': 'Typing Device', 'color': 'Black', 'category': 'Electronic', 'size': 0.0, 'made_in': 'India', 'ideal_for': '18+'}
# 1010 {'name': 'Alexa', 'pr': 2999, 'qn': 22, 'brand': 'Amazon', 'category': 'Electronic', 'color': 'Blue', 'customer_rating': 4, 'type': 'Speaker', 'size': 2.0, 'made_in': 'Aus', 'ideal_for': 'All'}
# 1011 {'name': 'Surf Excel', 'pr': 49, 'qn': 200, 'brand': 'Matic', 'category': 'Household Care', 'color': 'White', 'customer_rating': 5, 'type': 'Washing Powder', 'size': 2.0, 'made_in': 'India', 'ideal_for': 'All'}
# 1012 {'name': 'Lizol', 'pr': 120, 'qn': 129, 'brand': 'Nirma', 'category': 'Household care', 'color': 'Sky', 'customer_rating': 4, 'type': 'Washing Gel', 'size': 1.0, 'made_in': 'Aus', 'ideal_for': 'All'}
# 1013 {'name': 'Rin', 'pr': 20, 'qn': 40, 'brand': 'Big Bar', 'category': 'HouseHold Care\\', 'color': 'Green', 'customer_rating': 5, 'type': '', 'size': 200.0, 'made_in': 'india', 'ideal_for': 'all'}
# 1014 {'name': 'Ariel', 'pr': 20, 'qn': 200, 'brand': 'Tap Load', 'category': 'Household care', 'color': 'sky', 'customer_rating': 5, 'type': 'Washing Powder', 'size': 2.0, 'made_in': 'US', 'ideal_for': 'All'}
# 1015 {'name': 'Bottle', 'pr': 299, 'qn': 150, 'brand': 'Milton', 'category': 'Home Kitchen', 'color': 'Greenish-yellow', 'customer_rating': 4, 'type': 'Drinks Bottle', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1016 {'name': 'Maggi', 'pr': 10, 'qn': 210, 'brand': 'Maggi', 'category': 'Packeged Food', 'color': 'Normal', 'customer_rating': 5, 'type': 'Food', 'size': 2.0, 'made_in': 'China', 'ideal_for': 'All'}
# 1017 {'name': 'Lays', 'pr': 5, 'qn': 55, 'brand': 'Lay', 'category': 'Snacks', 'color': 'green', 'customer_rating': 5, 'type': 'Beverage', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1018 {'name': 'Red Lebel', 'pr': 139, 'qn': 200, 'brand': 'Brooke Bond', 'category': 'Grocery', 'color': 'Red', 'customer_rating': 5, 'type': 'Tea', 'size': 500.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1019 {'name': 'Biscuit', 'pr': 5, 'qn': 20, 'brand': 'Parle', 'category': 'Beverage', 'color': 'Normal', 'customer_rating': 4, 'type': 'Food', 'size': 2.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1020 {'name': 'Cofee', 'pr': 299, 'qn': 29, 'brand': 'Nescafe', 'category': 'Beverage', 'color': 'Black', 'customer_rating': 4, 'type': 'Drinks', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1021 {'name': 'Soft Drinks', 'pr': 99, 'qn': 20, 'brand': 'Coca', 'category': 'Beverage', 'color': 'black\\', 'customer_rating': 3, 'type': 'Drinks', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1022 {'name': 'Water ', 'pr': 20, 'qn': 20, 'brand': 'Aquafina', 'category': 'Driking Water', 'color': 'Normal', 'customer_rating': 5, 'type': 'Fresh water', 'size': 1.0, 'made_in': 'inia', 'ideal_for': 'all'}
# 1023 {'name': 'Dettol', 'pr': 29, 'qn': 20, 'brand': 'Dettol', 'category': 'Personal Care', 'color': 'Normal', 'customer_rating': 4, 'type': 'insectless', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1024 {'name': 'Apple Phone', 'pr': 290000, 'qn': 12, 'brand': 'Apple', 'category': 'Mobiles', 'color': 'Blue', 'customer_rating': 5, 'type': 'Cell phone', 'size': 1.0, 'made_in': 'Usa', 'ideal_for': 'Young'}
# 1025 {'name': 'Samsung Phone', 'pr': 29000, 'qn': 12, 'brand': 'Samsung', 'category': 'Mobiles', 'color': 'White', 'customer_rating': 4, 'type': 'Phone', 'size': 1.0, 'made_in': 'India', 'ideal_for': 'all'}
# 1026 {'name': 'Realme Phone', 'pr': 12000, 'qn': 12, 'brand': 'Realme', 'category': 'Monbles', 'color': 'Sky blur', 'customer_rating': 3, 'type': 'Phone', 'size': 1.0, 'made_in': 'Ind', 'ideal_for': 'all'}
# 1027 {'name': 'Ear buds', 'pr': 1200, 'qn': 25, 'brand': 'Realme', 'category': 'Electronic', 'color': 'White', 'customer_rating': 3, 'type': 'Speker', 'size': 1.0, 'made_in': 'Ind', 'ideal_for': 'young'}
# 1028 {'name': 'Smart Watch', 'pr': 12000, 'qn': 15, 'brand': 'Sony', 'category': 'Electronic', 'color': 'All', 'customer_rating': 4, 'type': 'Watch', 'size': 1.0, 'made_in': 'ind', 'ideal_for': 'all'}
# 1029 {'name': 'Camera', 'pr': 29000, 'qn': 15, 'brand': 'DSLR', 'category': 'Electronic', 'color': 'All', 'customer_rating': 5, 'type': 'photo click', 'size': 2.0, 'made_in': 'ind', 'ideal_for': 'all'}
# 1030 {'name': 'Power Bnak', 'pr': 12000, 'qn': 4, 'brand': 'mi', 'category': 'electronic', 'color': 'all', 'customer_rating': 4, 'type': 'charging', 'size': 1.0, 'made_in': 'ind', 'ideal_for': 'all'}
# 1031 {'name': 'oppo phone', 'pr': 20000, 'qn': 22, 'brand': 'oppo', 'category': 'elrctronic', 'color': 'all', 'customer_rating': 4, 'type': 'phone', 'size': 1.0, 'made_in': 'ind', 'ideal_for': 'young'}
# 1032 {'name': 'MI A1', 'pr': 12000, 'qn': 3, 'brand': 'MI', 'category': 'Elect', 'color': 'A', 'customer_rating': 4, 'type': 'Mobile', 'size': 1.0, 'made_in': 'ind', 'ideal_for': 'all'}
# 1033 {'name': 'washing machine', 'pr': 120000, 'qn': 5, 'brand': 'sony', 'category': 'electronic', 'color': 'all', 'customer_rating': 3, 'type': 'Washing elct', 'size': 1.0, 'made_in': 'america', 'ideal_for': 'all'}
# ******************************************
#
# Enter the product_Id: 1030
# Enter the quantity: 5
# Sorry, We are not having that much of quantity.
# We're only having 4 quantity.
# Would you like to purchase or not (Y/N)
# Y/NY
# Name: Power Bnak
# Price: 12000
# Quantity: 4
# ------------------------------
# Billing Amount: 48000
# ------------------------------
# Data Updated in Sales File!
# Data Updated in Inventory File!

# %%
dct
# Out:
# {'1001': {'name': 'Mobile',
#   'qn': 34,
#   'pr': 10000,
#   'brand': 'Realme',
#   'customer_rating': 4,
#   'type': 'Smartphone',
#   'color': 'Black',
#   'category': 'Mobiles',
#   'size': 7.0,
#   'made_in': 'India',
#   'ideal_for': '18+'},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'brand': 'Amool',
#   'customer_rating': 5,
#   'type': 'Bakery',
#   'color': 'Black',
#   'category': 'Beverage',
#   'size': 20.0,
#   'made_in': 'India',
#   'ideal_for': 'All'},
#  '1003': {'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'brand': 'Coca',
#   'customer_rating': 4,
#   'type': 'Drinks',
#   'color': 'Black',
#   'category': 'Beverage',
#   'size': 2.0,
#   'made_in': 'India',
#   'ideal_for': 'All'},
#  '1004': {'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'brand': 'Crush',
#   'customer_rating': 2,
#   'type': 'Time Pass',
#   'color': 'White',
#   'category': 'Beverage',
#   'size': 7.0,
#   'made_in': 'USA',
#   'ideal_for': 'All'},
#  '1005': {'name': 'Pen',
#   'pr': 20,
#   'qn': 100,
#   'brand': 'Golden Delta',
#   'customer_rating': 4,
#   'type': 'Writing Pen',
#   'color': 'Red',
#   'category': 'Stationary',
#   'size': 0.0,
#   'made_in': 'French',
#   'ideal_for': 'All'},
#  '1006': {'name': 'Laptop',
#   'pr': 50000,
#   'qn': 10,
#   'brand': 'Lenovo',
#   'customer_rating': 4,
#   'type': 'Computer',
#   'color': 'Black',
#   'category': 'Electronic',
#   'size': 0.0,
#   'made_in': 'China',
#   'ideal_for': '18+'},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 0,
#   'brand': 'Boat',
#   'customer_rating': 4,
#   'type': 'Audio_input',
#   'color': 'Grey',
#   'category': 'Electronics',
#   'size': 0.0,
#   'made_in': 'Japan',
#   'ideal_for': '18+'},
#  '1008': {'name': 'Smart Watch',
#   'pr': 1999,
#   'qn': 5,
#   'brand': 'Realme',
#   'customer_rating': 5,
#   'type': 'Hand Watch',
#   'color': 'Orange',
#   'category': 'Electronic',
#   'size': 5.0,
#   'made_in': 'India',
#   'ideal_for': '18+'},
#  '1009': {'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10,
#   'brand': 'PanaSonic',
#   'customer_rating': 4,
#   'type': 'Typing Device',
#   'color': 'Black',
#   'category': 'Electronic',
#   'size': 0.0,
#   'made_in': 'India',
#   'ideal_for': '18+'},
#  '1010': {'name': 'Alexa',
#   'pr': 2999,
#   'qn': 22,
#   'brand': 'Amazon',
#   'category': 'Electronic',
#   'color': 'Blue',
#   'customer_rating': 4,
#   'type': 'Speaker',
#   'size': 2.0,
#   'made_in': 'Aus',
#   'ideal_for': 'All'},
#  '1011': {'name': 'Surf Excel',
#   'pr': 49,
#   'qn': 200,
#   'brand': 'Matic',
#   'category': 'Household Care',
#   'color': 'White',
#   'customer_rating': 5,
#   'type': 'Washing Powder',
#   'size': 2.0,
#   'made_in': 'India',
#   'ideal_for': 'All'},
#  '1012': {'name': 'Lizol',
#   'pr': 120,
#   'qn': 129,
#   'brand': 'Nirma',
#   'category': 'Household care',
#   'color': 'Sky',
#   'customer_rating': 4,
#   'type': 'Washing Gel',
#   'size': 1.0,
#   'made_in': 'Aus',
#   'ideal_for': 'All'},
#  '1013': {'name': 'Rin',
#   'pr': 20,
#   'qn': 40,
#   'brand': 'Big Bar',
#   'category': 'HouseHold Care\\',
#   'color': 'Green',
#   'customer_rating': 5,
#   'type': '',
#   'size': 200.0,
#   'made_in': 'india',
#   'ideal_for': 'all'},
#  '1014': {'name': 'Ariel',
#   'pr': 20,
#   'qn': 200,
#   'brand': 'Tap Load',
#   'category': 'Household care',
#   'color': 'sky',
#   'customer_rating': 5,
#   'type': 'Washing Powder',
#   'size': 2.0,
#   'made_in': 'US',
#   'ideal_for': 'All'},
#  '1015': {'name': 'Bottle',
#   'pr': 299,
#   'qn': 150,
#   'brand': 'Milton',
#   'category': 'Home Kitchen',
#   'color': 'Greenish-yellow',
#   'customer_rating': 4,
#   'type': 'Drinks Bottle',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1016': {'name': 'Maggi',
#   'pr': 10,
#   'qn': 210,
#   'brand': 'Maggi',
#   'category': 'Packeged Food',
#   'color': 'Normal',
#   'customer_rating': 5,
#   'type': 'Food',
#   'size': 2.0,
#   'made_in': 'China',
#   'ideal_for': 'All'},
#  '1017': {'name': 'Lays',
#   'pr': 5,
#   'qn': 55,
#   'brand': 'Lay',
#   'category': 'Snacks',
#   'color': 'green',
#   'customer_rating': 5,
#   'type': 'Beverage',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1018': {'name': 'Red Lebel',
#   'pr': 139,
#   'qn': 200,
#   'brand': 'Brooke Bond',
#   'category': 'Grocery',
#   'color': 'Red',
#   'customer_rating': 5,
#   'type': 'Tea',
#   'size': 500.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1019': {'name': 'Biscuit',
#   'pr': 5,
#   'qn': 20,
#   'brand': 'Parle',
#   'category': 'Beverage',
#   'color': 'Normal',
#   'customer_rating': 4,
#   'type': 'Food',
#   'size': 2.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1020': {'name': 'Cofee',
#   'pr': 299,
#   'qn': 29,
#   'brand': 'Nescafe',
#   'category': 'Beverage',
#   'color': 'Black',
#   'customer_rating': 4,
#   'type': 'Drinks',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1021': {'name': 'Soft Drinks',
#   'pr': 99,
#   'qn': 20,
#   'brand': 'Coca',
#   'category': 'Beverage',
#   'color': 'black\\',
#   'customer_rating': 3,
#   'type': 'Drinks',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1022': {'name': 'Water ',
#   'pr': 20,
#   'qn': 20,
#   'brand': 'Aquafina',
#   'category': 'Driking Water',
#   'color': 'Normal',
#   'customer_rating': 5,
#   'type': 'Fresh water',
#   'size': 1.0,
#   'made_in': 'inia',
#   'ideal_for': 'all'},
#  '1023': {'name': 'Dettol',
#   'pr': 29,
#   'qn': 20,
#   'brand': 'Dettol',
#   'category': 'Personal Care',
#   'color': 'Normal',
#   'customer_rating': 4,
#   'type': 'insectless',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1024': {'name': 'Apple Phone',
#   'pr': 290000,
#   'qn': 12,
#   'brand': 'Apple',
#   'category': 'Mobiles',
#   'color': 'Blue',
#   'customer_rating': 5,
#   'type': 'Cell phone',
#   'size': 1.0,
#   'made_in': 'Usa',
#   'ideal_for': 'Young'},
#  '1025': {'name': 'Samsung Phone',
#   'pr': 29000,
#   'qn': 12,
#   'brand': 'Samsung',
#   'category': 'Mobiles',
#   'color': 'White',
#   'customer_rating': 4,
#   'type': 'Phone',
#   'size': 1.0,
#   'made_in': 'India',
#   'ideal_for': 'all'},
#  '1026': {'name': 'Realme Phone',
#   'pr': 12000,
#   'qn': 12,
#   'brand': 'Realme',
#   'category': 'Monbles',
#   'color': 'Sky blur',
#   'customer_rating': 3,
#   'type': 'Phone',
#   'size': 1.0,
#   'made_in': 'Ind',
#   'ideal_for': 'all'},
#  '1027': {'name': 'Ear buds',
#   'pr': 1200,
#   'qn': 25,
#   'brand': 'Realme',
#   'category': 'Electronic',
#   'color': 'White',
#   'customer_rating': 3,
#   'type': 'Speker',
#   'size': 1.0,
#   'made_in': 'Ind',
#   'ideal_for': 'young'},
#  '1028': {'name': 'Smart Watch',
#   'pr': 12000,
#   'qn': 15,
#   'brand': 'Sony',
#   'category': 'Electronic',
#   'color': 'All',
#   'customer_rating': 4,
#   'type': 'Watch',
#   'size': 1.0,
#   'made_in': 'ind',
#   'ideal_for': 'all'},
#  '1029': {'name': 'Camera',
#   'pr': 29000,
#   'qn': 15,
#   'brand': 'DSLR',
#   'category': 'Electronic',
#   'color': 'All',
#   'customer_rating': 5,
#   'type': 'photo click',
#   'size': 2.0,
#   'made_in': 'ind',
#   'ideal_for': 'all'},
#  '1030': {'name': 'Power Bnak',
#   'pr': 12000,
#   'qn': 4,
#   'brand': 'mi',
#   'category': 'electronic',
#   'color': 'all',
#   'customer_rating': 4,
#   'type': 'charging',
#   'size': 1.0,
#   'made_in': 'ind',
#   'ideal_for': 'all'},
#  '1031': {'name': 'oppo phone',
#   'pr': 20000,
#   'qn': 22,
#   'brand': 'oppo',
#   'category': 'elrctronic',
#   'color': 'all',
#   'customer_rating': 4,
#   'type': 'phone',
#   'size': 1.0,
#   'made_in': 'ind',
#   'ideal_for': 'young'},
#  '1032': {'name': 'MI A1',
#   'pr': 12000,
#   'qn': 3,
#   'brand': 'MI',
#   'category': 'Elect',
#   'color': 'A',
#   'customer_rating': 4,
#   'type': 'Mobile',
#   'size': 1.0,
#   'made_in': 'ind',
#   'ideal_for': 'all'},
#  '1033': {'name': 'washing machine',
#   'pr': 120000,
#   'qn': 5,
#   'brand': 'sony',
#   'category': 'electronic',
#   'color': 'all',
#   'customer_rating': 3,
#   'type': 'Washing elct',
#   'size': 1.0,
#   'made_in': 'america',
#   'ideal_for': 'all'}}

# %%
sales
# Out:
# {'0.6529563917217177': {'prod': '1022',
#   'qn': 2,
#   'amount': 40,
#   'prodname': 'Water '},
#  '0.32109430317413634': {'prod': '1029',
#   'qn': 2,
#   'amount': 58000,
#   'prodname': 'Camera'},
#  '0.21578618546286632': {'prod': '1019',
#   'qn': 1,
#   'amount': 5,
#   'prodname': 'Biscuit'},
#  '0.19466268510900975': {'prod': '1021',
#   'qn': 2,
#   'amount': 198,
#   'prodname': 'Soft Drinks'},
#  '0.8972999754200661': {'prod': '1010',
#   'qn': 3,
#   'amount': 8997,
#   'prodname': 'Alexa'},
#  '0.017949198805656263': {'prod': '1013',
#   'qn': 3,
#   'amount': 60,
#   'prodname': 'Rin'},
#  '0.6048744536260815': {'prod': '1021',
#   'qn': 2,
#   'amount': 198,
#   'prodname': 'Soft Drinks'},
#  '0.10433700308964156': {'prod': '1014',
#   'qn': 10,
#   'amount': 200,
#   'prodname': 'Ariel'},
#  '0.21937124001317954': {'prod': '1008',
#   'qn': 1,
#   'amount': 1999,
#   'prodname': 'Smart Watch'},
#  '0.051556868342424456': {'prod': '1009',
#   'qn': 2,
#   'amount': 3998,
#   'prodname': 'Keyboard'},
#  '0.47297787320061824': {'prod': '1010',
#   'qn': 3,
#   'amount': 8997,
#   'prodname': 'Alexa'},
#  '12': {'prod_id': '1030',
#   'time_pr': 'Thu Sep  9 08:02:11 2021',
#   'bill': 180000,
#   'qn': 15,
#   'pr': 12000,
#   'pr_name': 'Power Bnak'},
#  '13': {'prod_id': '1030',
#   'time_pr': 'Thu Sep  9 08:07:59 2021',
#   'bill': 0,
#   'qn': 0,
#   'pr': 12000,
#   'pr_name': 'Power Bnak'}}
