# %%
import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

records = json.loads(r)

# %%
records
# Out:
# {'1001': {'brand': 'Realme',
#   'category': 'Mobiles',
#   'color': 'Black',
#   'customer_rating': 4,
#   'ideal_for': '18+',
#   'made_in': 'India',
#   'name': 'Mobile',
#   'pr': 10000,
#   'qn': 34,
#   'size': 7.0,
#   'type': 'Smartphone'},
#  '1002': {'brand': 'Amool',
#   'category': 'Beverage',
#   'color': 'Black',
#   'customer_rating': 5,
#   'ideal_for': 'All',
#   'made_in': 'India',
#   'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'size': 20.0,
#   'type': 'Bakery'},
#  '1003': {'brand': 'Coca',
#   'category': 'Beverage',
#   'color': 'Black',
#   'customer_rating': 4,
#   'ideal_for': 'All',
#   'made_in': 'India',
#   'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'size': 2.0,
#   'type': 'Drinks'},
#  '1004': {'brand': 'Crush',
#   'category': 'Beverage',
#   'color': 'White',
#   'customer_rating': 2,
#   'ideal_for': 'All',
#   'made_in': 'USA',
#   'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'size': 7.0,
#   'type': 'Time Pass'},
# ...

# %% [markdown]
# # **Purchase and update inventory**

# %%
ui_prod  = str(input("Enter the product_Id: "))
print("Quantity available For this Product: ", records[ui_prod]['qn'])
ui_quant = int(input("Enter the quantity: "))

if( records[ui_prod]['qn'] < ui_quant and records[ui_prod]['qn'] > 0):
  print("Products of this id", ui_prod , "is only available in the inventory is" , records[ui_prod]['qn'] , " ..")
  print("So Please purchase less or equal to ", records[ui_prod]['qn'] , " ")
elif(records[ui_prod]['qn'] <= 0):
  print("No items available for this ", ui_prod , "So Please Purchase other things")
else:
  print("Product: ", records[ui_prod]['name'])
  print("Price: ", records[ui_prod]['pr'])
  print("Billing Amount: ", records[ui_prod]['pr'] * ui_quant)
  records[ui_prod]['qn'] = records[ui_prod]['qn'] - ui_quant

js = json.dumps(records)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product_Id: 1010
# Quantity available For this Product:  22
# Enter the quantity: 3
# Product:  Alexa
# Price:  2999
# Billing Amount:  8997

# %% [markdown]
# # **Sales**

# %%
import json

fd = open("sale.json",'r')
r = fd.read()
fd.close()

sales = json.loads(r)

# %%
import random
t_id = random.random()

sales[t_id] = {'prod' : ui_prod, 'qn' : ui_quant, 'amount': records[ui_prod]['pr'] * ui_quant, 'prodname': records[ui_prod]['name']}

jsn = json.dumps(sales)
fd = open("sale.json",'w')
fd.write(jsn)
fd.close()
sales
# Out:
# {'0.017949198805656263': {'amount': 60,
#   'prod': '1013',
#   'prodname': 'Rin',
#   'qn': 3},
#  0.051556868342424456: {'amount': 3998,
#   'prod': '1009',
#   'prodname': 'Keyboard',
#   'qn': 2},
#  0.10433700308964156: {'amount': 200,
#   'prod': '1014',
#   'prodname': 'Ariel',
#   'qn': 10},
#  '0.19466268510900975': {'amount': 198,
#   'prod': '1021',
#   'prodname': 'Soft Drinks',
#   'qn': 2},
#  '0.21578618546286632': {'amount': 5,
#   'prod': '1019',
#   'prodname': 'Biscuit',
#   'qn': 1},
#  0.21937124001317954: {'amount': 1999,
#   'prod': '1008',
#   'prodname': 'Smart Watch',
#   'qn': 1},
#  '0.32109430317413634': {'amount': 58000,
#   'prod': '1029',
#   'prodname': 'Camera',
#   'qn': 2},
#  0.47297787320061824: {'amount': 8997,
#   'prod': '1010',
#   'prodname': 'Alexa',
#   'qn': 3},
#  0.6048744536260815: {'amount': 198,
#   'prod': '1021',
#   'prodname': 'Soft Drinks',
#   'qn': 2},
#  '0.6529563917217177': {'amount': 40,
#   'prod': '1022',
# ...
